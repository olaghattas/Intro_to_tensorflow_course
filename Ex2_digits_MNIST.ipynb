# %% [markdown]
# # Exercise 2
# In the course you learned how to do classification using Fashion MNIST, a data set containing items of clothing. There's another, similar dataset called MNIST which has items of handwriting -- the digits 0 through 9.
#
# Write an MNIST classifier that trains to 99% accuracy or above, and does it without a fixed number of epochs -- i.e. you should stop training once you reach that level of accuracy.
#
# Some notes:
#
# 1.   It should succeed in less than 10 epochs, so it is okay to change epochs to 10, but nothing larger
# 2.   When it reaches 99% or greater it should print out the string "Reached 99% accuracy so cancelling training!"
# 3.  If you add any additional variables, make sure you use the same names as the ones used in the class
#
# I've started the code for you below -- how would you finish it?

# %%
# YOUR CODE SHOULD START HERE

# YOUR CODE SHOULD END HERE
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
# YOUR CODE SHOULD START HERE
x_train = x_train / 255.0
x_test = x_test / 255.0
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if (logs.get('accuracy') > 0.99):
      print('cancel training')
      self.model.stop_training= True
callbacks = myCallback()

# YOUR CODE SHOULD END HERE
model = tf.keras.models.Sequential([
# YOUR CODE SHOULD START HERE
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(units = 512, activation = 'relu'),
tf.keras.layers.Dense(units =10, activation = 'softmax')
# YOUR CODE SHOULD END HERE
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# YOUR CODE SHOULD START HERE
model.fit(x_train,y_train,epochs =20, callbacks = callbacks)
# YOUR CODE SHOULD END HERE
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1994 - accuracy: 0.9421
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0819 - accuracy: 0.9755
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0531 - accuracy: 0.9837
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0366 - accuracy: 0.9883
# Epoch 5/20
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9910cancel training
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0275 - accuracy: 0.9910

# %%
import numpy as np
import matplotlib.pyplot as plt
index = 6
print(model.predict(x_test)[index])
print(y_test[index])
plt.imshow(x_test[index])
# Out:
# [2.4115646e-13 5.6065247e-08 2.3477260e-09 6.3950589e-10 9.9997807e-01
#  1.4735361e-09 3.7490927e-10 1.4794736e-06 1.8909559e-05 1.4177165e-06]
# 4
