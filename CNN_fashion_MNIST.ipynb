# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
mnist = keras.datasets.fashion_mnist
(x_train, y_train),(x_test,y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_train = x_train/255.0
x_test = x_test.reshape(10000,28,28,1)
x_test = x_test/255.0

# %%
model = keras.Sequential([keras.layers.Conv2D(64,(3,3),activation='relu',input_shape= (28,28,1)),
                          keras.layers.MaxPooling2D(2,2),
                          keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                          keras.layers.MaxPooling2D(2,2),
                          keras.layers.Flatten(),
                          keras.layers.Dense(units = 128,activation = 'relu'),
                          keras.layers.Dense(10,activation='softmax')
                          ])
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model
model.fit(x_train,y_train,epochs = 5)
print(model.predict(x_test)[8])
test_loss = model.evaluate(x_test,y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 82s 43ms/step - loss: 0.4421
# Epoch 2/5
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.2986
# Epoch 3/5
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.2505
# Epoch 4/5
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.2171
# Epoch 5/5
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.1913
# [8.7134941e-07 1.0459354e-08 9.0420897e-08 9.6723074e-09 1.9906649e-07
#  9.9990797e-01 1.0365698e-07 6.1592495e-05 2.9027218e-05 1.0002553e-07]
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2440

# %%
print(y_test[8])
# Out:
# 5
